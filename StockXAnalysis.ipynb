# %% [markdown]
# <a href="https://colab.research.google.com/github/etroop11/StockXAnalysis/blob/master/StockXAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install stockx-py-sdk

# %%
import pandas as pd
import numpy as np
import json
#import stockxsdk as stkx
from stockxsdk import Stockx

# %%
##Authentication doesnt seem to be working

# %%
stockx = Stockx()
product_id = stockx.search('A')
json.dumps(product_id)
#90d7808c-36cc-4dec-8ee5-3b548b918467
# Out:
# '[{"name": "Jordan 1 Retro High Tokyo Bio Hack", "brand": "Jordan", "thumbnail_url": "https://stockx.imgix.net/Air-Jordan-1-Retro-High-Bio-Hack-Product.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1599068019", "media": {"imageUrl": "https://stockx.imgix.net/Air-Jordan-1-Retro-High-Bio-Hack-Product.jpg?fit=fill&bg=FFFFFF&w=700&h=500&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1599068019", "smallImageUrl": "https://stockx.imgix.net/Air-Jordan-1-Retro-High-Bio-Hack-Product.jpg?fit=fill&bg=FFFFFF&w=300&h=214&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1599068019", "thumbUrl": "https://stockx.imgix.net/Air-Jordan-1-Retro-High-Bio-Hack-Product.jpg?fit=fill&bg=FFFFFF&w=140&h=100&auto=format,compress&trim=color&q=90&dpr=2&updated_at=1599068019", "gallery": [], "hidden": false}, "url": "air-jordan-1-retro-high-bio-hack", "release_date": "2020-09-04", "categories": ["Air Jordan", "One"], "product_category": "sneakers", "ticker_sym
# ...
